# %%
# !pip install roboflow -q
# !pip install ultralytics -q
# !pip install pillow -q
# !pip install matplotlib -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 43.2 MB/s eta 0:00:00

# %%
from roboflow import Roboflow
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO
model_pretrained = YOLO("/content/yolo11n.pt") # Pretreained model contain clusters
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to '/content/yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 285MB/s]

# %%
image_path = "/content/taksim.jpg"
image = Image.open(image_path)

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
results = model_pretrained(image)

# Plot detection boundaires
detection_image = results[0].plot(show=False)  # Fence image detected
plt.imshow(detection_image)  # Show results with matplotlib
plt.axis('off')
plt.show()
# Out:
# 0: 384x640 14 persons, 1 truck, 1 handbag, 122.8ms
# Speed: 24.1ms preprocess, 122.8ms inference, 1206.7ms postprocess per image at shape (1, 3, 384, 640)
